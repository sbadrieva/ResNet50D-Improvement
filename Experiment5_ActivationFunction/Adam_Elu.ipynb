# %%
# !git clone https://github.com/rwightman/pytorch-image-models
# Out:
# Cloning into 'pytorch-image-models'...
# remote: Enumerating objects: 10258, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 10258 (delta 34), reused 46 (delta 31), pack-reused 10201
# Receiving objects: 100% (10258/10258), 19.90 MiB | 20.62 MiB/s, done.
# Resolving deltas: 100% (7549/7549), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/pytorch-image-models/
# Out:
# /content/pytorch-image-models

# %%
# !python train.py 1   --model resnet50d --sched cosine --epochs 40 --warmup-epochs 5 --lr 5e-3 --bce-target-thresh 0.2  --smoothing 0.1 --mixup 0.2 --batch-size 32 --amp -j 2 --opt adam
# Out:
# Training with a single process on 1 GPUs.
# Model resnet50d created, param count:25576264
# Data processing configuration for current model + dataset:
# 	input_size: (3, 224, 224)
# 	interpolation: bicubic
# 	mean: (0.485, 0.456, 0.406)
# 	std: (0.229, 0.224, 0.225)
# 	crop_pct: 0.875
# Using native Torch AMP. Training in mixed precision.
# Scheduled epochs: 50
# Train: 0 [   0/304 (  0%)]  Loss: 6.933 (6.93)  Time: 12.940s,    2.47/s  (12.940s,    2.47/s)  LR: 1.000e-04  Data: 8.570 (8.570)
# Train: 0 [  50/304 ( 17%)]  Loss: 3.314 (4.69)  Time: 0.180s,  178.23/s  (3.962s,    8.08/s)  LR: 1.000e-04  Data: 0.003 (3.693)
# Train: 0 [ 100/304 ( 33%)]  Loss: 2.517 (3.82)  Time: 0.173s,  185.15/s  (3.809s,    8.40/s)  LR: 1.000e-04  Data: 0.002 (3.581)
# Train: 0 [ 150/304 ( 50%)]  Loss: 2.623 (3.47)  Time: 1.668s,   19.18/s  (3.701s,    8.65/s)  LR: 1.000e-04  Data: 1.500 (3.487)
# ...

# %%
# !python validate.py /content/drive/MyDrive/imagenette2-320/val/ --model resnet50d --checkpoint ./output/train/20220512-162824-resnet50d-224/checkpoint-44.pth.tar
# Out:
# Validating in float32. AMP not enabled.
# Loaded state_dict from checkpoint './output/train/20220512-162824-resnet50d-224/checkpoint-44.pth.tar'
# Model resnet50d created, param count: 25576264
# Data processing configuration for current model + dataset:
# 	input_size: (3, 224, 224)
# 	interpolation: bicubic
# 	mean: (0.485, 0.456, 0.406)
# 	std: (0.229, 0.224, 0.225)
# 	crop_pct: 0.875
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Test: [   0/16]  Time: 6.369s (6.369s,   40.19/s)  Loss:  0.3288 (0.3288)  Acc@1:  95.312 ( 95.312)  Acc@5:  99.219 ( 99.219)
# ...

# %%
# !python inference.py /content/drive/MyDrive/imagenette2-320/val/ --model resnet50d --checkpoint ./output/train/20220512-162824-resnet50d-224/checkpoint-44.pth.tar
# Out:
# Loaded state_dict from checkpoint './output/train/20220512-162824-resnet50d-224/checkpoint-44.pth.tar'
# Model resnet50d created, param count: 25576264
# Predict: [0/16] Time 7.761 (7.761)
# Predict: [10/16] Time 1.301 (1.723)

# %%
# !python validate.py /content/drive/MyDrive/imagenette2-320/val/ --model resnet50d --checkpoint ./output/train/20220512-162824-resnet50d-224/checkpoint-45.pth.tar
# Out:
# Validating in float32. AMP not enabled.
# Loaded state_dict from checkpoint './output/train/20220512-162824-resnet50d-224/checkpoint-45.pth.tar'
# Model resnet50d created, param count: 25576264
# Data processing configuration for current model + dataset:
# 	input_size: (3, 224, 224)
# 	interpolation: bicubic
# 	mean: (0.485, 0.456, 0.406)
# 	std: (0.229, 0.224, 0.225)
# 	crop_pct: 0.875
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Test: [   0/16]  Time: 6.834s (6.834s,   37.46/s)  Loss:  0.3233 (0.3233)  Acc@1:  94.922 ( 94.922)  Acc@5:  99.219 ( 99.219)
# ...

# %%
# !python validate.py /content/drive/MyDrive/imagenette2-320/val/ --model resnet50d --checkpoint ./output/train/20220512-162824-resnet50d-224/checkpoint-39.pth.tar
# Out:
# Validating in float32. AMP not enabled.
# Loaded state_dict from checkpoint './output/train/20220512-162824-resnet50d-224/checkpoint-39.pth.tar'
# Model resnet50d created, param count: 25576264
# Data processing configuration for current model + dataset:
# 	input_size: (3, 224, 224)
# 	interpolation: bicubic
# 	mean: (0.485, 0.456, 0.406)
# 	std: (0.229, 0.224, 0.225)
# 	crop_pct: 0.875
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Test: [   0/16]  Time: 5.805s (5.805s,   44.10/s)  Loss:  0.3384 (0.3384)  Acc@1:  95.312 ( 95.312)  Acc@5:  99.219 ( 99.219)
# ...

# %%
import csv

#this will need to be changed
with open('/content/summary-adam_elu.csv') as File:  
    Line_reader = csv.reader(File)

# %%
import matplotlib.pyplot as plt 
from matplotlib.pyplot import figure
import pandas as pd
import csv 

plt.rcParams["figure.figsize"] = [7.00, 5.00]
plt.rcParams["figure.autolayout"] = True

columns = ['train_loss', 'eval_loss']


df = pd.read_csv("/content/summary-adam_elu.csv", usecols = columns)
  


df.columns=['Training Loss','Validation Loss']

df.plot()

plt.legend(loc='upper right')

plt.xlabel('Epochs') 

plt.ylabel('Loss Value') 

plt.title('Training and Validation Loss') 
plt.legend() 
plt.show()

# %%
import matplotlib.pyplot as plt 
from matplotlib.pyplot import figure
import pandas as pd
import csv 

plt.rcParams["figure.figsize"] = [7.00, 5.00]
plt.rcParams["figure.autolayout"] = True

columns = ['eval_top1', 'eval_top5']


df = pd.read_csv("/content/summary-adam_elu.csv", usecols = columns)
  


df.columns=['Validation Top 1','Validation Top 5']

df.plot()

plt.legend(loc='lower right')

plt.xlabel('Epochs') 

plt.ylabel('Validation Value') 

plt.title('Top 1 & Top 5 Validation Accuracy') 
plt.legend() 
plt.show()
